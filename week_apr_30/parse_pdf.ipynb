# %%
from tabula import read_pdf_table
# Out:
# ----------------------------------------------------------------
# ImportError                    Traceback (most recent call last)
# <ipython-input-5-00b9d9783ddc> in <module>()
# ----> 1 from tabula import read_pdf_table
#
# ImportError: cannot import name 'read_pdf_table'

# %%
import tabula

# %%
table = tabula.read_pdf("nics_data.pdf")

# %%
table.to_csv("nics_data.csv", index=False)

# %%
import pandas as pd

# %%
table = pd.read_csv("nics_data.csv")

# %%
table
# Out:
#     Year        Jan        Feb        Mar        Apr        May        Jun  \
# 0   1998        NaN        NaN        NaN        NaN        NaN        NaN
# 1   1999    591,355    696,323    753,083    646,712    576,272    569,493
# 2   2000    639,972    707,070    736,543    617,689    538,648    550,561
# 3   2001    640,528    675,156    729,532    594,723    543,501    540,491
# 4   2002    665,803    694,668    714,665    627,745    569,247    518,351
# 5   2003    653,751    708,281    736,864    622,832    567,436    529,334
# 6   2004    695,000    723,654    738,298    642,589    542,456    546,847
# 7   2005    685,811    743,070    768,290    658,954    557,058    555,560
# 8   2006    775,518    820,679    845,219    700,373    626,270    616,097
# 9   2007    894,608    914,954    975,806    840,271    803,051    792,943
# 10  2008    942,556  1,021,130  1,040,863    940,961    886,183    819,891
# ...

# %%
table_fixed = pd.read_csv("nics_data.csv", thousands=",")

# %%
table_fixed["Jan"].apply(pd.to_numeric)
# Out:
# 0           NaN
# 1      591355.0
# 2      639972.0
# 3      640528.0
# 4      665803.0
# 5      653751.0
# 6      695000.0
# 7      685811.0
# 8      775518.0
# 9      894608.0
# 10     942556.0
# 11    1213885.0
# 12    1119229.0
# 13    1323336.0
# 14    1377301.0
# 15    2495440.0
# 16    1660355.0
# 17    1772794.0
# 18    2545802.0
# 19    2043184.0
# 20    2030530.0
# Name: Jan, dtype: float64

# %%
table_fixed["Jan"] + table_fixed["Feb"]
# Out:
# 0           NaN
# 1     1287678.0
# 2     1347042.0
# 3     1315684.0
# 4     1360471.0
# 5     1362032.0
# 6     1418654.0
# 7     1428881.0
# 8     1596197.0
# 9     1809562.0
# 10    1963686.0
# 11    2472963.0
# 12    2362440.0
# 13    2796849.0
# 14    3127204.0
# 15    4804833.0
# 16    3747218.0
# 17    3632378.0
# 18    5158876.0
# 19    4278001.0
# 20    4363723.0
# dtype: float64

# %%
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

# %%
col = table_fixed["Jan"] + table_fixed["Feb"] + table_fixed["Mar"] + table_fixed["Apr"] + table_fixed["May"] + table_fixed["Jun"] + table_fixed["Jul"] + table_fixed["Aug"] + table_fixed["Sep"] + table_fixed["Oct"] + table_fixed["Nov"] + table_fixed["Dec"]
col.sum()
# Out:
# 277559540.0

# %%
table_fixed["Totals"]
table_fixed["Totals"][1:20].sum()
# Out:
# 277559540

# %%
table_fixed[months].sum(axis=1)
# Out:
# 0       892840.0
# 1      9138123.0
# 2      8543037.0
# 3      8910191.0
# 4      8454322.0
# 5      8481588.0
# 6      8687671.0
# 7      8952945.0
# 8     10036933.0
# 9     11177335.0
# 10    12709023.0
# 11    14033824.0
# 12    14409616.0
# 13    16454951.0
# 14    19592303.0
# 15    21093273.0
# 16    20968547.0
# 17    23141970.0
# 18    27538673.0
# 19    25235215.0
# 20     7131422.0
# dtype: float64
